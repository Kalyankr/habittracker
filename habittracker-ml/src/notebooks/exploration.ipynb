# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parents[1]))

import pandas as pd
import xgboost
from src.data.make_dataset import load_batches

# %%
root_path = Path("../../data/raw")
print(root_path)
data = load_batches(root_path)
# Out:
# ../../data/raw

# %%
data
# Out:
#                        time  seconds_elapsed  rotationRateX  rotationRateY  \
# 0       1766786011765202000         8.639202       0.005488       0.007029
# 1       1766786011775131000         8.649131       0.007207      -0.000763
# 2       1766786011785061000         8.659061       0.010243      -0.005449
# 3       1766786011794990000         8.668990       0.014257      -0.003978
# 4       1766786011804920000         8.678920       0.010446      -0.007097
# ...                     ...              ...            ...            ...
# 115186  1766801838824071200       302.507071      -0.255914       0.265530
# 115187  1766801838834000100       302.517000      -0.256076       0.215858
# 115188  1766801838843929300       302.526929      -0.278475       0.166736
# 115189  1766801838853858300       302.536858      -0.347343       0.116898
# 115190  1766801838863787300       302.546787      -0.447098       0.048721
#
# ...
